# %%
from typing import TypedDict
import requests

class CSEAuth(TypedDict):
    cse_id: str
    api_key: str

def validate_cse_auth(
    auth: CSEAuth,
) -> bool:
    """
    Validate the CSEAuth dictionary.

    Args:
        auth (CSEAuth): The CSEAuth dictionary to validate.

    Returns:
        bool: True if valid, False otherwise.
    """
    return all(key in auth for key in ["cse_id", "api_key"])


def validate_image(
    image_url: str,
    ) -> bool:
    
    if not image_url or image_url == "" or not isinstance(image_url, str):
        print(f"Invalid image URL. Expected a non-empty string, found: '{image_url}'")
        return False

    try:
        response = requests.head(image_url)
        return response.status_code >= 200 and response.status_code < 400
    except Exception as e:
        print(f"Error checking image URI: {e}")
        return False

# %%
import os
from googleapiclient.discovery import build
from typing import Any, Dict


def custom_search(
    cse_auth: CSEAuth,
    image_url: str,
) -> Dict[str, Any]:
    
    if not validate_cse_auth(cse_auth):
        print("Invalid CSEAuth dictionary.")
        return {}
    if not validate_image(image_url):
        print("Invalid image URL.")
        return {}
    
    service = build("customsearch", "v1", developerKey=cse_auth["api_key"])

    return service.cse().list(
        q=image_url,
        cx=cse_auth["cse_id"],
        searchType="image",
        ).execute()

# %%
import sys
import os

# Add the absolute path to the project root
project_root = os.path.abspath("..")
sys.path.append(project_root)

# %%
import configparser

with open("../secrets/cse_auth.ini", "r") as f:
    content = f.read()

config = configparser.ConfigParser()
config.read_string(content)

cse_auth: CSEAuth = {
    "cse_id": config["CSE_AUTH"]["CSE_ID"],
    "api_key": config["CSE_AUTH"]["CSE_API_KEY"],
    }

image_url = "https://assets.philosophie.ch/2023-08-10-erni.jpeg"

# %%
res = custom_search(
    cse_auth=cse_auth,
    image_url=image_url,
)

# %%
res
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - image search',
#     'totalResults': '731920000000',
#     'searchTerms': 'image search',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '5061d1605d3b34fba',
#     'searchType': 'image'}],
#   'nextPage': [{'title': 'Google Custom Search - image search',
#     'totalResults': '731920000000',
#     'searchTerms': 'image search',
#     'count': 10,
#     'startIndex': 11,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '5061d1605d3b34fba',
#     'searchType': 'image'}]},
#  'context': {'title': 'philoch-copyright-check'},
#  'searchInformation': {'searchTime': 0.447836,
#   'formattedSearchTime': '0.45',
#   'totalResults': '731920000000',
#   'formattedTotalResults': '731,920,000,000'},
#  'items': [{'kind': 'customsearch#result',
#    'title': 'Introducing ChatGPT search | OpenAI',
#    'htmlTitle': 'Introducing ChatGPT <b>search</b> | OpenAI',
#    'link': 'https://images.ctfassets.net/kftzwdyauwt9/7LzxdzMcijUYHtIES6rmub/1dd3bc9f423a6b1cd5176936dbb029aa/Entry_Point.png?w=3840&q=90&fm=webp',
#    'displayLink': 'openai.com',
#    'snippet': 'Introducing ChatGPT search | OpenAI',
#    'htmlSnippet': 'Introducing ChatGPT <b>search</b> | OpenAI',
#    'mime': 'image/png',
#    'fileFormat': 'image/png',
#    'image': {'contextLink': 'https://openai.com/index/introducing-chatgpt-search/',
#     'height': 2160,
#     'width': 3840,
#     'byteSize': 88732,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRan2pQPI8GJ4TKDqXuwDb67SBqEI3hAW4SDoL7ZdpSPJjq32lV2M2ZtA&s',
#     'thumbnailHeight': 84,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'Reach More Customers with Paid Search Advertising - Google Ads',
#    'htmlTitle': 'Reach More Customers with Paid <b>Search</b> Advertising - Google Ads',
#    'link': 'https://lh3.googleusercontent.com/Mlj6ERl0WjgBwc_bpdrVp_rjB4utgziXy-qoPkcSxlH3HRbfVp3p8x9i993x5tW_1ypkIybUdgs6u8-G5LWKXVX9tv8F1WpkmMqIXE0nNlrQUOzMzw=w400-rw-v1',
#    'displayLink': 'ads.google.com',
#    'snippet': 'Reach More Customers with Paid Search Advertising - Google Ads',
#    'htmlSnippet': 'Reach More Customers with Paid <b>Search</b> Advertising - Google Ads',
#    'mime': 'image/',
#    'fileFormat': 'image/',
#    'image': {'contextLink': 'https://ads.google.com/home/campaigns/search-ads/',
#     'height': 405,
#     'width': 400,
#     'byteSize': 8994,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSRmswe-1449X1uJn75hJOelUnEB5o9V81_7jYbLQ4Ad6VTdZk9Thc-cw&s',
#     'thumbnailHeight': 124,
#     'thumbnailWidth': 122}},
#   {'kind': 'customsearch#result',
#    'title': "Web Browser vs. Search Engine: What's the Difference? | ExpressVPN ...",
#    'htmlTitle': 'Web Browser vs. <b>Search</b> Engine: What&#39;s the Difference? | ExpressVPN ...',
#    'link': 'https://s22908.pcdn.co/wp-content/uploads/2023/05/browsers-vs-search-engines.jpg',
#    'displayLink': 'www.expressvpn.com',
#    'snippet': "Web Browser vs. Search Engine: What's the Difference? | ExpressVPN ...",
#    'htmlSnippet': 'Web Browser vs. <b>Search</b> Engine: What&#39;s the Difference? | ExpressVPN ...',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://www.expressvpn.com/blog/browser-vs-search-engine/',
#     'height': 1282,
#     'width': 1940,
#     'byteSize': 45092,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThBRaAohdcpbSADfJlHVf7g82uUV2USI0YXasn2-JezyDCoTiwzlojKF0&s',
#     'thumbnailHeight': 99,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'How to use Google Lens in Chrome Desktop (Search Faster) - YouTube',
#    'htmlTitle': 'How to use Google Lens in Chrome Desktop (<b>Search</b> Faster) - YouTube',
#    'link': 'https://i.ytimg.com/vi/kqrURUUuvgs/maxresdefault.jpg',
#    'displayLink': 'www.youtube.com',
#    'snippet': 'How to use Google Lens in Chrome Desktop (Search Faster) - YouTube',
#    'htmlSnippet': 'How to use Google Lens in Chrome Desktop (<b>Search</b> Faster) - YouTube',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://www.youtube.com/watch?v=kqrURUUuvgs',
#     'height': 720,
#     'width': 1280,
#     'byteSize': 94233,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcReWCWp8QrlqyGTSk6f88RhIKXYWdXgXnitV1SOgVqYNIwijIX4z-51_gs&s',
#     'thumbnailHeight': 84,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'Search Box for addresses, places, and POI | Mapbox',
#    'htmlTitle': '<b>Search</b> Box for addresses, places, and POI | Mapbox',
#    'link': 'https://cdn.prod.website-files.com/6050a76fa6a633d5d54ae714/642be30ada547980c2c8b481_search-box__colout_01.jpg',
#    'displayLink': 'www.mapbox.com',
#    'snippet': 'Search Box for addresses, places, and POI | Mapbox',
#    'htmlSnippet': '<b>Search</b> Box for addresses, places, and POI | Mapbox',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://www.mapbox.com/search-box',
#     'height': 1001,
#     'width': 1460,
#     'byteSize': 128367,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQSrMjtFC82NuTvO1828XKvhnUywlNZzlR_x6De4dnS9SYeOoF_rF1HoPA&s',
#     'thumbnailHeight': 103,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'The best AI search engines | Zapier',
#    'htmlTitle': 'The best AI <b>search</b> engines | Zapier',
#    'link': 'https://images.ctfassets.net/lzny33ho1g45/6tllXnwt9V6dLq61kkMziY/fdff45f41605a7b2561bde1c44a7cc62/best-ai-search-engines.jpg?w=1520&fm=jpg&q=31&fit=thumb&h=760',
#    'displayLink': 'zapier.com',
#    'snippet': 'The best AI search engines | Zapier',
#    'htmlSnippet': 'The best AI <b>search</b> engines | Zapier',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://zapier.com/blog/best-ai-search-engine/',
#     'height': 760,
#     'width': 1520,
#     'byteSize': 40400,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQOm26QG33qJyDU1ZTPozQ788dhcyqJ2dU1bPi6xJyyKvqPr90ZygqQ4g&s',
#     'thumbnailHeight': 75,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'Search Box for addresses, places, and POI | Mapbox',
#    'htmlTitle': '<b>Search</b> Box for addresses, places, and POI | Mapbox',
#    'link': 'https://cdn.prod.website-files.com/6050a76fa6a633d5d54ae714/643c4fc7931a3b3729ee8342_search_box-automotive.jpg',
#    'displayLink': 'www.mapbox.com',
#    'snippet': 'Search Box for addresses, places, and POI | Mapbox',
#    'htmlSnippet': '<b>Search</b> Box for addresses, places, and POI | Mapbox',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://www.mapbox.com/search-box',
#     'height': 850,
#     'width': 1240,
#     'byteSize': 107848,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR1QxkdjFMf-78bYaWW-ghOa6moAtQcELxXFKynJBw2wZ7JQwmjbWhZGg&s',
#     'thumbnailHeight': 103,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'How to reverse image search on iPhone, Android, and your computer ...',
#    'htmlTitle': 'How to reverse image <b>search</b> on iPhone, Android, and your computer ...',
#    'link': 'https://images.ctfassets.net/lzny33ho1g45/7vluy8Gf7IOypeUjHAb86x/f35d4221129daa9fd860f938b76cc3f7/how-to-reverse-image-search-image05.png?w=1400',
#    'displayLink': 'zapier.com',
#    'snippet': 'How to reverse image search on iPhone, Android, and your computer ...',
#    'htmlSnippet': 'How to reverse image <b>search</b> on iPhone, Android, and your computer ...',
#    'mime': 'image/png',
#    'fileFormat': 'image/png',
#    'image': {'contextLink': 'https://zapier.com/blog/how-to-reverse-image-search/',
#     'height': 467,
#     'width': 1400,
#     'byteSize': 217749,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSs0kVD9BOlNCIIL8sXXI630QGgR5W3GIzMt-KgbQAdGBxiN0__dovWizM&s',
#     'thumbnailHeight': 50,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'How to search better: 17 essential tips, plus best practices',
#    'htmlTitle': 'How to <b>search</b> better: 17 essential tips, plus best practices',
#    'link': 'https://able.ac/blog/content/images/2022/10/person-clicking-the-search-icon.jpeg',
#    'displayLink': 'able.ac',
#    'snippet': 'How to search better: 17 essential tips, plus best practices',
#    'htmlSnippet': 'How to <b>search</b> better: 17 essential tips, plus best practices',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://able.ac/blog/how-to-search-better/',
#     'height': 660,
#     'width': 1200,
#     'byteSize': 23596,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTHl1y6FKfWsOMgbwAK_8L7oMWwN8JdkrjM1IQ4N263VOvx4XPEQu8FD_k&s',
#     'thumbnailHeight': 83,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'Search - Opera Help',
#    'htmlTitle': '<b>Search</b> - Opera Help',
#    'link': 'https://www-static-sites.operacdn.com/wp-content/uploads/sites/2/2020/09/help-page_search-box-1024x349.jpg',
#    'displayLink': 'help.opera.com',
#    'snippet': 'Search - Opera Help',
#    'htmlSnippet': '<b>Search</b> - Opera Help',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://help.opera.com/en/latest/search/',
#     'height': 349,
#     'width': 1024,
#     'byteSize': 23202,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT7Q420wpf_84-17J5AyFUZv70fE8Stom-ud03lA73AAyBM3A48uCH6Ig&s',
#     'thumbnailHeight': 51,
#     'thumbnailWidth': 150}}]}

# %%
def reverse_image_search(image_url):
    api_key = "your_serpapi_key"
    params = {
        "engine": "google_reverse_image",
        "image_url": image_url,
        "api_key": api_key
    }
    response = requests.get("https://serpapi.com/search", params=params)
    return response.json()

# %%
def search_similar_images(cse_auth: CSEAuth, image_url):

    search_url = 'https://www.googleapis.com/customsearch/v1'

    params = {
        'q': 'image search',
        'searchType': 'image',
        'imgUrl': image_url,
        'key': cse_auth['api_key'],
        'cx': cse_auth['cse_id']
    }
    response = requests.get(search_url, params=params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        return response.json()

# %%
res = search_similar_images(
    cse_auth=cse_auth,
    image_url=image_url,
)

# %%
res
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - image search',
#     'totalResults': '731920000000',
#     'searchTerms': 'image search',
#     'count': 10,
#     'startIndex': 1,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '5061d1605d3b34fba',
#     'searchType': 'image'}],
#   'nextPage': [{'title': 'Google Custom Search - image search',
#     'totalResults': '731920000000',
#     'searchTerms': 'image search',
#     'count': 10,
#     'startIndex': 11,
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '5061d1605d3b34fba',
#     'searchType': 'image'}]},
#  'context': {'title': 'philoch-copyright-check'},
#  'searchInformation': {'searchTime': 0.447836,
#   'formattedSearchTime': '0.45',
#   'totalResults': '731920000000',
#   'formattedTotalResults': '731,920,000,000'},
#  'items': [{'kind': 'customsearch#result',
#    'title': 'Introducing ChatGPT search | OpenAI',
#    'htmlTitle': 'Introducing ChatGPT <b>search</b> | OpenAI',
#    'link': 'https://images.ctfassets.net/kftzwdyauwt9/7LzxdzMcijUYHtIES6rmub/1dd3bc9f423a6b1cd5176936dbb029aa/Entry_Point.png?w=3840&q=90&fm=webp',
#    'displayLink': 'openai.com',
#    'snippet': 'Introducing ChatGPT search | OpenAI',
#    'htmlSnippet': 'Introducing ChatGPT <b>search</b> | OpenAI',
#    'mime': 'image/png',
#    'fileFormat': 'image/png',
#    'image': {'contextLink': 'https://openai.com/index/introducing-chatgpt-search/',
#     'height': 2160,
#     'width': 3840,
#     'byteSize': 88732,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRan2pQPI8GJ4TKDqXuwDb67SBqEI3hAW4SDoL7ZdpSPJjq32lV2M2ZtA&s',
#     'thumbnailHeight': 84,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'Reach More Customers with Paid Search Advertising - Google Ads',
#    'htmlTitle': 'Reach More Customers with Paid <b>Search</b> Advertising - Google Ads',
#    'link': 'https://lh3.googleusercontent.com/Mlj6ERl0WjgBwc_bpdrVp_rjB4utgziXy-qoPkcSxlH3HRbfVp3p8x9i993x5tW_1ypkIybUdgs6u8-G5LWKXVX9tv8F1WpkmMqIXE0nNlrQUOzMzw=w400-rw-v1',
#    'displayLink': 'ads.google.com',
#    'snippet': 'Reach More Customers with Paid Search Advertising - Google Ads',
#    'htmlSnippet': 'Reach More Customers with Paid <b>Search</b> Advertising - Google Ads',
#    'mime': 'image/',
#    'fileFormat': 'image/',
#    'image': {'contextLink': 'https://ads.google.com/home/campaigns/search-ads/',
#     'height': 405,
#     'width': 400,
#     'byteSize': 8994,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSRmswe-1449X1uJn75hJOelUnEB5o9V81_7jYbLQ4Ad6VTdZk9Thc-cw&s',
#     'thumbnailHeight': 124,
#     'thumbnailWidth': 122}},
#   {'kind': 'customsearch#result',
#    'title': "Web Browser vs. Search Engine: What's the Difference? | ExpressVPN ...",
#    'htmlTitle': 'Web Browser vs. <b>Search</b> Engine: What&#39;s the Difference? | ExpressVPN ...',
#    'link': 'https://s22908.pcdn.co/wp-content/uploads/2023/05/browsers-vs-search-engines.jpg',
#    'displayLink': 'www.expressvpn.com',
#    'snippet': "Web Browser vs. Search Engine: What's the Difference? | ExpressVPN ...",
#    'htmlSnippet': 'Web Browser vs. <b>Search</b> Engine: What&#39;s the Difference? | ExpressVPN ...',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://www.expressvpn.com/blog/browser-vs-search-engine/',
#     'height': 1282,
#     'width': 1940,
#     'byteSize': 45092,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcThBRaAohdcpbSADfJlHVf7g82uUV2USI0YXasn2-JezyDCoTiwzlojKF0&s',
#     'thumbnailHeight': 99,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'How to use Google Lens in Chrome Desktop (Search Faster) - YouTube',
#    'htmlTitle': 'How to use Google Lens in Chrome Desktop (<b>Search</b> Faster) - YouTube',
#    'link': 'https://i.ytimg.com/vi/kqrURUUuvgs/maxresdefault.jpg',
#    'displayLink': 'www.youtube.com',
#    'snippet': 'How to use Google Lens in Chrome Desktop (Search Faster) - YouTube',
#    'htmlSnippet': 'How to use Google Lens in Chrome Desktop (<b>Search</b> Faster) - YouTube',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://www.youtube.com/watch?v=kqrURUUuvgs',
#     'height': 720,
#     'width': 1280,
#     'byteSize': 94233,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcReWCWp8QrlqyGTSk6f88RhIKXYWdXgXnitV1SOgVqYNIwijIX4z-51_gs&s',
#     'thumbnailHeight': 84,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'Search Box for addresses, places, and POI | Mapbox',
#    'htmlTitle': '<b>Search</b> Box for addresses, places, and POI | Mapbox',
#    'link': 'https://cdn.prod.website-files.com/6050a76fa6a633d5d54ae714/642be30ada547980c2c8b481_search-box__colout_01.jpg',
#    'displayLink': 'www.mapbox.com',
#    'snippet': 'Search Box for addresses, places, and POI | Mapbox',
#    'htmlSnippet': '<b>Search</b> Box for addresses, places, and POI | Mapbox',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://www.mapbox.com/search-box',
#     'height': 1001,
#     'width': 1460,
#     'byteSize': 128367,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQSrMjtFC82NuTvO1828XKvhnUywlNZzlR_x6De4dnS9SYeOoF_rF1HoPA&s',
#     'thumbnailHeight': 103,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'The best AI search engines | Zapier',
#    'htmlTitle': 'The best AI <b>search</b> engines | Zapier',
#    'link': 'https://images.ctfassets.net/lzny33ho1g45/6tllXnwt9V6dLq61kkMziY/fdff45f41605a7b2561bde1c44a7cc62/best-ai-search-engines.jpg?w=1520&fm=jpg&q=31&fit=thumb&h=760',
#    'displayLink': 'zapier.com',
#    'snippet': 'The best AI search engines | Zapier',
#    'htmlSnippet': 'The best AI <b>search</b> engines | Zapier',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://zapier.com/blog/best-ai-search-engine/',
#     'height': 760,
#     'width': 1520,
#     'byteSize': 40400,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQOm26QG33qJyDU1ZTPozQ788dhcyqJ2dU1bPi6xJyyKvqPr90ZygqQ4g&s',
#     'thumbnailHeight': 75,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'Search Box for addresses, places, and POI | Mapbox',
#    'htmlTitle': '<b>Search</b> Box for addresses, places, and POI | Mapbox',
#    'link': 'https://cdn.prod.website-files.com/6050a76fa6a633d5d54ae714/643c4fc7931a3b3729ee8342_search_box-automotive.jpg',
#    'displayLink': 'www.mapbox.com',
#    'snippet': 'Search Box for addresses, places, and POI | Mapbox',
#    'htmlSnippet': '<b>Search</b> Box for addresses, places, and POI | Mapbox',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://www.mapbox.com/search-box',
#     'height': 850,
#     'width': 1240,
#     'byteSize': 107848,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR1QxkdjFMf-78bYaWW-ghOa6moAtQcELxXFKynJBw2wZ7JQwmjbWhZGg&s',
#     'thumbnailHeight': 103,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'How to reverse image search on iPhone, Android, and your computer ...',
#    'htmlTitle': 'How to reverse image <b>search</b> on iPhone, Android, and your computer ...',
#    'link': 'https://images.ctfassets.net/lzny33ho1g45/7vluy8Gf7IOypeUjHAb86x/f35d4221129daa9fd860f938b76cc3f7/how-to-reverse-image-search-image05.png?w=1400',
#    'displayLink': 'zapier.com',
#    'snippet': 'How to reverse image search on iPhone, Android, and your computer ...',
#    'htmlSnippet': 'How to reverse image <b>search</b> on iPhone, Android, and your computer ...',
#    'mime': 'image/png',
#    'fileFormat': 'image/png',
#    'image': {'contextLink': 'https://zapier.com/blog/how-to-reverse-image-search/',
#     'height': 467,
#     'width': 1400,
#     'byteSize': 217749,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSs0kVD9BOlNCIIL8sXXI630QGgR5W3GIzMt-KgbQAdGBxiN0__dovWizM&s',
#     'thumbnailHeight': 50,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'How to search better: 17 essential tips, plus best practices',
#    'htmlTitle': 'How to <b>search</b> better: 17 essential tips, plus best practices',
#    'link': 'https://able.ac/blog/content/images/2022/10/person-clicking-the-search-icon.jpeg',
#    'displayLink': 'able.ac',
#    'snippet': 'How to search better: 17 essential tips, plus best practices',
#    'htmlSnippet': 'How to <b>search</b> better: 17 essential tips, plus best practices',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://able.ac/blog/how-to-search-better/',
#     'height': 660,
#     'width': 1200,
#     'byteSize': 23596,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTHl1y6FKfWsOMgbwAK_8L7oMWwN8JdkrjM1IQ4N263VOvx4XPEQu8FD_k&s',
#     'thumbnailHeight': 83,
#     'thumbnailWidth': 150}},
#   {'kind': 'customsearch#result',
#    'title': 'Search - Opera Help',
#    'htmlTitle': '<b>Search</b> - Opera Help',
#    'link': 'https://www-static-sites.operacdn.com/wp-content/uploads/sites/2/2020/09/help-page_search-box-1024x349.jpg',
#    'displayLink': 'help.opera.com',
#    'snippet': 'Search - Opera Help',
#    'htmlSnippet': '<b>Search</b> - Opera Help',
#    'mime': 'image/jpeg',
#    'fileFormat': 'image/jpeg',
#    'image': {'contextLink': 'https://help.opera.com/en/latest/search/',
#     'height': 349,
#     'width': 1024,
#     'byteSize': 23202,
#     'thumbnailLink': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT7Q420wpf_84-17J5AyFUZv70fE8Stom-ud03lA73AAyBM3A48uCH6Ig&s',
#     'thumbnailHeight': 51,
#     'thumbnailWidth': 150}}]}

# %%
def reverse_image_search(image_url):
    api_key = "your_serpapi_key"
    params = {
        "engine": "google_reverse_image",
        "image_url": image_url,
        "api_key": api_key
    }
    response = requests.get("https://serpapi.com/search", params=params)
    return response.json()

# %%
import cv2
import pytesseract

def detect_watermark(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    text = pytesseract.image_to_string(gray)
    
    if "copyright" in text.lower() or "©" in text:
        return f"Watermark detected in {image_path}"
    return "No watermark found"

# %%
detect_watermark("data-copyrighted-imgs/2023-10-15-luporini.jpg")
# Out:
# 'No watermark found'
